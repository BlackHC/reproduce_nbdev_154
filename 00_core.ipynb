# %%
# default_exp core

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
# exports

class A:
    """The Class A."""
    def __init__(self, value):
        self.value = value
# Out:
# UsageError: Line magic function `%` not found.

# %%
# exports different_module

class B:
    """The Class A."""
    def __init__(self, value):
        self.value = value

# %% [markdown]
# ```
# FileNotFoundError: [Errno 2] No such file or directory: '/home/blackhc/PycharmProjects/reproduce_nbdev_154/nbdev_template/different_module.py'
# ```
#
# Needed to rename 00_core to 02_core. Nope does not help. I had to comment it out first!!!
# However, `# exports different_module` did not actually export anything.
#
# `different_module.py` does not contain the cell!
#
# ```
# # AUTOGENERATED! DO NOT EDIT! File to edit: 01_different_module.ipynb (unless otherwise specified).
#
# __all__ = ['DEFAULT_EXPORT_WORKS']
#
# # Cell
#
# DEFAULT_EXPORT_WORKS=1
# ```
